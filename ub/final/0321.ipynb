# %%
#야후파이낸스 라이브러리 
import yfinance as yf

# %%
import pandas as pd

# %%
yf.download('AAPL',sart = '2021-01-01')  #end 없으면 오늘까지
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100323
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095089
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088110
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090291
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092908
# ...                ...         ...         ...         ...         ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  150.619995
# 2022-03-15  150.899994  155.570007  150.380005  155.089996  155.089996
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  159.589996
# 2022-03-17  158.610001  161.000000  157.630005  160.619995  160.619995
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
#
#                Volume
# Date
# ...

# %%
data = yf.download(['AAPL','TSLA','AMZN','CPNG'],start="2021-01-10")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
data['Close']['CPNG']
# Out:
# Date
# 2021-01-11          NaN
# 2021-01-12          NaN
# 2021-01-13          NaN
# 2021-01-14          NaN
# 2021-01-15          NaN
#                 ...
# 2022-03-14    16.120001
# 2022-03-15    15.450000
# 2022-03-16    18.090000
# 2022-03-17    19.200001
# 2022-03-18    19.240000
# Name: CPNG, Length: 300, dtype: float64

# %%
aapl = yf.Ticker("AAPL")

# %%
#배당내역
a = pd.DataFrame(aapl.dividends)
a['1991-02-15':'1992-02-14']
# Out:
#             Dividends
# Date
# 1991-02-15   0.001071
# 1991-05-20   0.001071
# 1991-08-19   0.001071
# 1991-11-18   0.001071
# 1992-02-14   0.001071

# %%
#주식분할
aapl.splits
# Out:
# Date
# 1987-06-16    2.0
# 2000-06-21    2.0
# 2005-02-28    2.0
# 2014-06-09    7.0
# 2020-08-31    4.0
# Name: Stock Splits, dtype: float64

# %%
#애널리스트평가
aapl.recommendations
# Out:
#                                     Firm      To Grade From Grade Action
# Date
# 2012-02-09 08:17:00    Canaccord Genuity           Buy              main
# 2012-03-08 07:33:00       FBN Securities    Outperform              main
# 2012-03-13 06:08:00            Jefferies           Buy              main
# 2012-03-14 06:13:00       Morgan Stanley    Overweight              main
# 2012-03-14 08:21:00    Canaccord Genuity           Buy              main
# ...                                  ...           ...        ...    ...
# 2022-01-28 14:19:01  New Street Research       Neutral       Sell     up
# 2022-01-28 15:10:56          Oppenheimer    Outperform              main
# 2022-01-31 15:44:19        Credit Suisse       Neutral              main
# 2022-02-15 15:31:58    Tigress Financial    Strong Buy              main
# 2022-03-11 11:57:08             Barclays  Equal-Weight              main
#
# [831 rows x 4 columns]

# %%
#회사 정보
pd.DataFrame(pd.Series(aapl.info))
# Out:
#                                                                      0
# zip                                                              95014
# sector                                                      Technology
# fullTimeEmployees                                               100000
# longBusinessSummary  Apple Inc. designs, manufactures, and markets ...
# city                                                         Cupertino
# ...                                                                ...
# dayHigh                                                         164.48
# regularMarketPrice                                              163.98
# preMarketPrice                                                    None
# logo_url                           https://logo.clearbit.com/apple.com
# trailingPegRatio                                                3.0052
#
# [153 rows x 1 columns]

# %%
aapl.history(period='max')
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100323    0.100759    0.100323    0.100323  469033600
# 1980-12-15    0.095525    0.095525    0.095089    0.095089  175884800
# 1980-12-16    0.088546    0.088546    0.088110    0.088110  105728000
# 1980-12-17    0.090291    0.090727    0.090291    0.090291   86441600
# 1980-12-18    0.092908    0.093345    0.092908    0.092908   73449600
# ...                ...         ...         ...         ...        ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  108732100
# 2022-03-15  150.899994  155.570007  150.380005  155.089996   92964300
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  102300200
# 2022-03-17  158.610001  161.000000  157.630005  160.619995   75615400
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  123351200
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
cpng = yf.Ticker("CPNG")

# %%
a=cpng.history(start='2021-01-01')

# %%
cpng.info
# Out:
# {'zip': '05510',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 68000,
#  'longBusinessSummary': 'Coupang, Inc. owns and operates in e-commerce business through its mobile applications and Internet websites primarily in South Korea. It operates through two segments, Product Commerce and Growth Initiatives. The company sells various products and services in the categories of home goods and dÃ©cor products, apparel, beauty products, fresh food and groceries, sporting goods, electronics, and everyday consumables, as well as travel, and restaurant order and delivery services. It also performs operations and support services in China, Singapore, Japan, Taiwan, and the United States. Coupang, Inc. was incorporated in 2010 and is headquartered in Seoul, South Korea.',
#  'city': 'Seoul',
#  'phone': '82 2 6150 5422',
#  'country': 'South Korea',
#  'companyOfficers': [],
#  'website': 'https://www.coupang.com',
#  'maxAge': 1,
#  'address1': 'Tower 730,570',
# ...

# %%
#비트코인
import pyupbit as upbit

# %%
upbit.get_tickers(fiat = 'KRW')
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-LTC',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-OMG',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-LSK',
#  'KRW-STEEM',
#  'KRW-XLM',
#  'KRW-ARDR',
#  'KRW-ARK',
#  'KRW-STORJ',
#  'KRW-GRS',
#  'KRW-REP',
#  'KRW-ADA',
#  'KRW-SBD',
#  'KRW-POWR',
#  'KRW-BTG',
#  'KRW-ICX',
#  'KRW-EOS',
#  'KRW-TRX',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLY',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'KRW-BCH',
#  'KRW-BAT',
#  'KRW-IOST',
#  'KRW-RFR',
#  'KRW-CVC',
#  'KRW-IQ',
#  'KRW-IOTA',
#  'KRW-MFT',
#  'KRW-ONG',
#  'KRW-GAS',
#  'KRW-UPP',
#  'KRW-ELF',
#  'KRW-KNC',
#  'KRW-BSV',
#  'KRW-THETA',
#  'KRW-QKC',
#  'KRW-BTT',
#  'KRW-MOC',
#  'KRW-ENJ',
#  'KRW-TFUEL',
#  'KRW-MANA',
#  'KRW-ANKR',
#  'KRW-AERGO',
#  'KRW-ATOM',
#  'KRW-TT',
#  'KRW-CRE',
#  'KRW-MBL',
#  'KRW-WAXP',
#  'KRW-HBAR',
#  'KRW-MED',
#  'KRW-MLK',
#  'KRW-STPT',
#  'KRW-ORBS',
#  'KRW-VET',
#  'KRW-CHZ',
#  'KRW-STMX',
# ...

# %%
#코인의 현재가 확인하는 방법
upbit.get_current_price(["KRW-BTC", "KRW-ETH"])
# Out:
# {'KRW-BTC': 50061000.0, 'KRW-ETH': 3484000.0}

# %%
ticker= "KRW-BTC"
interval = "minute1"  #minute, week, month,day

to = "2022-01-01 00:00"
count = 100
upbit.get_ohlcv(ticker=ticker, interval=interval, count=10 )
# Out:
#                            open        high         low       close    volume  \
# 2022-03-21 13:11:00  49961000.0  49964000.0  49953000.0  49963000.0  3.251980
# 2022-03-21 13:12:00  49961000.0  49965000.0  49953000.0  49953000.0  1.918678
# 2022-03-21 13:13:00  49954000.0  49965000.0  49952000.0  49954000.0  3.983039
# 2022-03-21 13:14:00  49965000.0  50010000.0  49953000.0  49966000.0  4.900417
# 2022-03-21 13:15:00  49965000.0  50049000.0  49965000.0  50020000.0  2.774424
# 2022-03-21 13:16:00  50022000.0  50085000.0  50021000.0  50024000.0  5.216989
# 2022-03-21 13:17:00  50066000.0  50068000.0  50020000.0  50049000.0  2.499109
# 2022-03-21 13:18:00  50024000.0  50050000.0  50021000.0  50021000.0  5.206897
# 2022-03-21 13:19:00  50021000.0  50040000.0  49985000.0  50000000.0  3.493824
# 2022-03-21 13:20:00  49989000.0  50016000.0  49988000.0  49991000.0  2.878575
# 2022-03-21 13:21:00  49991000.0  50005000.0  49986000.0  49989000.0  2.283685
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] =(4,3)
plt.rcParams['font.size']= 12

cpng_open = a.Open
cpng_close = a.Close
cpng_high = a.High
cpng_low = a.Low

fig,ax = plt.subplot()
ax.boxplot([cpng_open,cpng_close,cpng_high,cpng_low],notch=True, whis=2.5)
ax.set_ylim(-10,10)
ax.set_xlabel('Coupang')
ax.set_ylabel('Price')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Ubion\final\0321.ipynb Cell 20' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Ubion/final/0321.ipynb#ch0000020?line=6'>7</a> cpng_high = a.High
#       <a href='vscode-notebook-cell:/c%3A/Ubion/final/0321.ipynb#ch0000020?line=7'>8</a> cpng_low = a.Low
# ---> <a href='vscode-notebook-cell:/c%3A/Ubion/final/0321.ipynb#ch0000020?line=9'>10</a> fig,ax = plt.subplot()
#      <a href='vscode-notebook-cell:/c%3A/Ubion/final/0321.ipynb#ch0000020?line=10'>11</a> ax.boxplot([cpng_open,cpng_close,cpng_high,cpng_low],notch=True, whis=2.5)
#      <a href='vscode-notebook-cell:/c%3A/Ubion/final/0321.ipynb#ch0000020?line=11'>12</a> ax.set_ylim(-10,10)
#
# TypeError: cannot unpack non-iterable AxesSubplot object
