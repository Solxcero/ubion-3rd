# %% [markdown]
# class 하나 생성
# 1. 인자값으로 url 받아오기 ->csv 파일 주소(상대경로)
# 2. 함수를 하나 생성 -> url에 있는 csv 파일을 읽어오고, 'Country' 기준으로  sort, 인덱스값 초기화
# 3. 함수를 하나 생성 -> 인자값을 리스트로 받기 -> 이 매개변수를 기준으로 columns 삭제

# %%
import pandas as pd

# %%
class Change_dt(): #self로 쓰면 클래스가 갖고 있는 변수임.
    def __init__(self, input_url):
        self.url = input_url

    def csv_read(self): #위에서 url 불어오니까 매개변수 필요없음 
        self.dt = pd.read_csv(self.url)
        self.dt.sort_values("Country",inplace=True)
        self.dt.reset_index(drop=True, inplace=True)
        return self.dt

    def remove_col(self, input_list): #매개변수라 self 안해도됨
        self.dt.drop(input_list, axis=1,inplace=True)
        return self.dt

dt = Change_dt("./csv/Sales Records.csv")

# %%
class Change_dt(): #self로 쓰면 클래스가 갖고 있는 변수임.
    def __init__(self, input_url):
        self.url = input_url

    def csv_read(self, input_sort, input_inplace): #위에서 url 불어오니까 매개변수 필요없음 
        self.dt = pd.read_csv(self.url)
        self.dt.sort_values(input_sort,inplace = input_inplace)
        self.dt.reset_index(drop=True, inplace = input_inplace)
        return self.dt

    def remove_col(self, input_list = [] ): #매개변수라 self 안해도됨
        self.dt.drop(input_list, axis=1,inplace=True)
        return self.dt

    def remove_2(self, input_s_col, input_e_col):
        self.dt.drop(self.dt.loc[:,input_s_col : input_e_col],axis=1,inplace=True)
        return self.dt

dt = Change_dt("./csv/Sales Records.csv")

# %%
dt.csv_read("Country",True).head()
# Out:
#                          Region      Country  Item Type Sales Channel  \
# 0  Middle East and North Africa  Afghanistan     Cereal       Offline
# 1  Middle East and North Africa  Afghanistan  Household       Offline
# 2  Middle East and North Africa  Afghanistan     Cereal       Offline
# 3  Middle East and North Africa  Afghanistan       Meat       Offline
# 4  Middle East and North Africa  Afghanistan  Household       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H  7/24/2013  933963477  8/23/2013        9402      205.70
# 1              L   2/4/2012  772306096  3/21/2012        1391      668.27
# 2              H  8/20/2015  667230880  10/5/2015        7300      205.70
# 3              H  8/11/2012  161685121  8/29/2012        5075      421.89
# 4              M  3/25/2011  440761888   4/1/2011          92      668.27
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
dt.remove_col(["Item Type","Sales Channel"]).tail()

# %%
dt.remove_2("Item Type","Order Date")
# Out:
#                             Region      Country   Order ID   Ship Date  \
# 0     Middle East and North Africa  Afghanistan  933963477   8/23/2013
# 1     Middle East and North Africa  Afghanistan  772306096   3/21/2012
# 2     Middle East and North Africa  Afghanistan  667230880   10/5/2015
# 3     Middle East and North Africa  Afghanistan  161685121   8/29/2012
# 4     Middle East and North Africa  Afghanistan  440761888    4/1/2011
# ...                            ...          ...        ...         ...
# 9995            Sub-Saharan Africa     Zimbabwe  742576920    2/6/2016
# 9996            Sub-Saharan Africa     Zimbabwe  322291505   2/11/2010
# 9997            Sub-Saharan Africa     Zimbabwe  436287105  11/27/2015
# 9998            Sub-Saharan Africa     Zimbabwe  433102357    2/3/2017
# 9999            Sub-Saharan Africa     Zimbabwe  486245286    2/5/2013
#
#       Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %%
dt.remove_col("Unit Cost")
# Out:
#                             Region      Country   Order ID   Ship Date  \
# 0     Middle East and North Africa  Afghanistan  933963477   8/23/2013
# 1     Middle East and North Africa  Afghanistan  772306096   3/21/2012
# 2     Middle East and North Africa  Afghanistan  667230880   10/5/2015
# 3     Middle East and North Africa  Afghanistan  161685121   8/29/2012
# 4     Middle East and North Africa  Afghanistan  440761888    4/1/2011
# ...                            ...          ...        ...         ...
# 9995            Sub-Saharan Africa     Zimbabwe  742576920    2/6/2016
# 9996            Sub-Saharan Africa     Zimbabwe  322291505   2/11/2010
# 9997            Sub-Saharan Africa     Zimbabwe  436287105  11/27/2015
# 9998            Sub-Saharan Africa     Zimbabwe  433102357    2/3/2017
# 9999            Sub-Saharan Africa     Zimbabwe  486245286    2/5/2013
#
#       Units Sold  Unit Price  Total Revenue  Total Cost  Total Profit
# ...

# %%
import mod1  #실제 라이브러리 처럼 불러오려면  path 설정으로 파일 경로 지정해주면 됨 
import imp    # 모듈 변경후 다시 작용하는 법 
imp.reload(mod1)
# Out:
# <module 'mod1' from 'c:\\Ubion\\python\\mod1.py'>

# %%
mod1.add(1,2)
# Out:
# -1
# -1

# %%
from module import mod2

# %%
mod2.sub(5,8)
# Out:
# -3
# -3

# %%
# mod3 파일 안에 아에 imp 라이브러리 넣어놓기 
import mod3

# %%
mod3.sub(3,4)
# Out:
# -1

# %%
mod3.add(2,3)
# Out:
# 5

# %%
#모듈로 작업해보기 
import change as ch
imp.reload(ch)
# Out:
# <module 'change' from 'c:\\Ubion\\python\\change.py'>

# %%
dt = ch.Change_dt("./csv/Sales Records.csv")

# %%
dt.csv_read("Country",True)
# Out:
#                             Region      Country        Item Type  \
# 0     Middle East and North Africa  Afghanistan           Cereal
# 1     Middle East and North Africa  Afghanistan        Household
# 2     Middle East and North Africa  Afghanistan           Cereal
# 3     Middle East and North Africa  Afghanistan             Meat
# 4     Middle East and North Africa  Afghanistan        Household
# ...                            ...          ...              ...
# 9995            Sub-Saharan Africa     Zimbabwe           Cereal
# 9996            Sub-Saharan Africa     Zimbabwe  Office Supplies
# 9997            Sub-Saharan Africa     Zimbabwe           Fruits
# 9998            Sub-Saharan Africa     Zimbabwe          Clothes
# 9999            Sub-Saharan Africa     Zimbabwe           Fruits
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0          Offline              H   7/24/2013  933963477   8/23/2013
# ...

# %%
class Class_1():
    def a(self):
        print("Class_1")

class Class_2():
    def b(self):
        print("Class_2")

class Class_3(Class_1,Class_2):  # 다중 상속 
    def c(self):
        print("Class_3")

x = Class_3()

# %%
x.a()
# Out:
# Class_1

# %%
x.c()
# Out:
# Class_3

# %%
x.b()
# Out:
# Class_2
